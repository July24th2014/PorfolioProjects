# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://coinmarketcap.com/currencies/bitcoin/'

page = requests.get(url)

soup = BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find('span', class_ = "sc-f70bb44c-0 jltoa")
# Out:
# <span class="sc-f70bb44c-0 jltoa" data-role="coin-name" title="Bitcoin">Bitcoin<span class="sc-f70bb44c-0 iQEJet coin-name-mobile"> price</span> </span>

# %%
soup.find('span', class_ = "sc-f70bb44c-0 jltoa").text
# Out:
# 'Bitcoin price\xa0'

# %%
<span class="sc-f70bb44c-0 jltoa" data-role="coin-name" title="Bitcoin">Bitcoin<span class="sc-f70bb44c-0 iQEJet coin-name-mobile"> price</span> </span>
# Out:
#   Cell In[6], line 1
#     <span class="sc-f70bb44c-0 jltoa" data-role="coin-name" title="Bitcoin">Bitcoin<span class="sc-f70bb44c-0 iQEJet coin-name-mobile"> price</span> </span>
#     ^
# SyntaxError: invalid syntax

# %%
crypto_name = soup.find('span', class_ = "sc-f70bb44c-0 jltoa").text
cleaned_crypto_name = crypto_name.replace('price ', '').strip()
print(cleaned_crypto_name)
# Out:
# Bitcoin

# %%
soup.find('span', class_ = "sc-f70bb44c-0 jxpCgO base-text")
# Out:
# <span class="sc-f70bb44c-0 jxpCgO base-text">$69,573.80</span>

# %%
soup.find('span', class_ = "sc-f70bb44c-0 jxpCgO base-text").text
# Out:
# '$69,573.80'

# %%
crypto_price = soup.find('span', class_ = "sc-f70bb44c-0 jxpCgO base-text").text
cleaned_crypto_price = crypto_price.replace('$','')
print(cleaned_crypto_price)
# Out:
# 69,573.80

# %%
import pandas as pd

# %%
from datetime import datetime
date_time = datetime.now()

print(date_time)
# Out:
# 2024-05-22 17:46:04.113483

# %%
date_time = datetime.now()

dict = {'Crypto Name' :cleaned_crypto_name,
        'Price' :cleaned_crypto_price,
       'TimeStamp': date_time}

df = pd.DataFrame([dict])
df
# Out:
#   Crypto Name      Price                  TimeStamp
# 0     Bitcoin  69,573.80 2024-05-22 17:46:10.942997

# %%
df.to_csv(r'C:\Users\chulu\OneDrive\Desktop\Data\Crypto_Web_Puller\Crypto_Automated.csv')

# %%
import os

# %%
if os.path.exists(r'C:\Users\chulu\OneDrive\Desktop\Data\Crypto_Web_Puller\Crypto_Automated.csv'):
    df.to_csv(r'C:\Users\chulu\OneDrive\Desktop\Data\Crypto_Web_Puller\Crypto_Automated.csv', mode='a', header=False, index=False)
else:
    df.to_csv(r'C:\Users\chulu\OneDrive\Desktop\Data\Crypto_Web_Puller\Crypto_Automated.csv', index=False)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime
import os
import time

# %%
def automated_crypto():
    url = 'https://coinmarketcap.com/currencies/bitcoin/'

    page = requests.get(url)

    soup = BeautifulSoup(page.text,'html')

    crypto_name = soup.find('span', class_ = "sc-f70bb44c-0 jltoa").text
    cleaned_crypto_name = crypto_name.replace('price ', '').strip()
    
    crypto_price = soup.find('span', class_ = "sc-f70bb44c-0 jxpCgO base-text").text
    cleaned_crypto_price = crypto_price.replace('$','')

    date_time = datetime.now()

    dict = {'Crypto Name' :cleaned_crypto_name,
        'Price' :cleaned_crypto_price,
       'TimeStamp': date_time}

    df = pd.DataFrame([dict])

    if os.path.exists(r'C:\Users\chulu\OneDrive\Desktop\Data\Crypto_Web_Puller\Crypto_Automated.csv'):
        df.to_csv(r'C:\Users\chulu\OneDrive\Desktop\Data\Crypto_Web_Puller\Crypto_Automated.csv', mode = 'a', header = False, index = False)
    else:
        df.to_csv(r'C:\Users\chulu\OneDrive\Desktop\Data\Crypto_Web_Puller\Crypto_Automated.csv',index=False)   
    print(df)

# %%
# Run the function every 10 seconds
while True:
    automated_crypto()
    time.sleep(3600)
# Out:
#   Crypto Name      Price                  TimeStamp
# 0     Bitcoin  69,498.30 2024-05-22 17:56:58.312404
#   Crypto Name      Price                  TimeStamp
# 0     Bitcoin  69,518.87 2024-05-22 17:57:08.404419
#   Crypto Name      Price                  TimeStamp
# 0     Bitcoin  69,518.87 2024-05-22 17:57:18.497283
#   Crypto Name      Price                  TimeStamp
# 0     Bitcoin  69,518.87 2024-05-22 17:57:28.603308
#   Crypto Name      Price                  TimeStamp
# 0     Bitcoin  69,518.87 2024-05-22 17:57:38.699473
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 4
#       2 while True:
#       3     automated_crypto()
# ----> 4     time.sleep(10)
#
# KeyboardInterrupt:
